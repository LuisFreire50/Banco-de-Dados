# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisFreire50/Banco-de-Dados/blob/main/Criando%20banco%20de%20dads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv")
df2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SCO0.csv")
df3 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/D1.csv")
df4 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I1.csv")
df5 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP1.csv")
df6 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F1.csv")
df7 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/N1.csv")
df8 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/B1.csv")
df9 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/P1.csv")
df10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/T1.csv")
df11= pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/G1.csv")
df12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E0.csv")
df13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SCO0.csv")
df14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/D1.csv")
df15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/I1.csv")
df16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SP1.csv")
df17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F1.csv")
df18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/N1.csv")
df19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/B1.csv")
df20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/P1.csv")
df21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/T1.csv")
df22= pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/G1.csv")
df23 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/E0.csv")
df24 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/SCO0.csv")
df25 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/D1.csv")
df26 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/I1.csv")
df27 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/SP1.csv")
df28 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/F1.csv")
df29 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/N1.csv")
df30 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/B1.csv")
df31 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/P1.csv")
df32 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/T1.csv")
df33= pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/G1.csv")

# %%
df = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20 ,df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33]
df = pd.concat(df)

# %%
df
# Out:
#     Div        Date   Time          HomeTeam          AwayTeam  FTHG  FTAG  \
# 0    E0  05/08/2022  20:00    Crystal Palace           Arsenal   0.0   2.0
# 1    E0  06/08/2022  12:30            Fulham         Liverpool   2.0   2.0
# 2    E0  06/08/2022  15:00       Bournemouth       Aston Villa   2.0   0.0
# 3    E0  06/08/2022  15:00             Leeds            Wolves   2.0   1.0
# 4    E0  06/08/2022  15:00         Newcastle     Nott'm Forest   2.0   0.0
# ..   ..         ...    ...               ...               ...   ...   ...
# 107  G1  22/12/2024  16:00     Panathinaikos  Athens Kallithea   1.0   0.0
# 108  G1  22/12/2024  17:30              PAOK         Atromitos   3.0   0.0
# 109  G1  22/12/2024  19:00               AEK       Levadeiakos   1.0   1.0
# 110  G1  23/12/2024  13:00  Asteras Tripolis              Aris   2.0   1.0
# 111  G1  23/12/2024  16:00         OFI Crete         Volos NFC   4.0   0.0
#
# ...

# %%
df.to_excel("Database Euro.xlsx")
